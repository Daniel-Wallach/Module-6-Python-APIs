# %% [markdown]
# # VacationPy
# ---
#
# ## Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import geopandas as gpd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0       constitucion -35.3333  -72.4167     11.04        83
# 1        1       puerto ayora  -0.7393  -90.3518     29.98        91
# 2        2  port-aux-francais -49.3500   70.2167      1.09        67
# 3        3  wailua homesteads  22.0669 -159.3780     28.24        74
# 4        4            college  64.8569 -147.8028     -1.03        86
#
#    Cloudiness  Wind Speed Country        Date
# 0          11        6.26      CL  1696978534
# 1          47        4.02      EC  1696978534
# 2          99       16.13      TF  1696978534
# 3          40        4.12      US  1696978534
# 4         100        3.60      US  1696978535

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM",
                                      responsive=True
                                     )

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_conditions = city_data_df[
    (city_data_df["Max Temp"] > 20) &
    (city_data_df["Max Temp"] < 30) &
    (city_data_df["Wind Speed"] < 4.5) &
    (city_data_df["Cloudiness"] <= 10)
]

# Drop any rows with null values
ideal_conditions.dropna()

# Display sample data
ideal_conditions.head()
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 22        22  conceicao da barra -18.5933  -39.7322     24.19        85
# 55        55      capo d'orlando  38.1435   14.7305     20.23        54
# 82        82      port macquarie -31.4333  152.9167     22.16        66
# 95        95              maceio  -9.6658  -35.7353     23.69       100
# 103      103              diboll  31.1871  -94.7810     27.16        61
#
#      Cloudiness  Wind Speed Country        Date
# 22            2        2.43      BR  1696978538
# 55            0        1.36      IT  1696978545
# 82            5        1.39      AU  1696977939
# 95            0        2.06      BR  1696978553
# 103           0        3.09      US  1696978344

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_conditions[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 22   conceicao da barra      BR -18.5933  -39.7322        85
# 55       capo d'orlando      IT  38.1435   14.7305        54
# 82       port macquarie      AU -31.4333  152.9167        66
# 95               maceio      BR  -9.6658  -35.7353       100
# 103              diboll      US  31.1871  -94.7810        61

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
import urllib.parse

# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    # Append the parameters to the base URL to create the full API URL
    full_api_url = f"{base_url}?{urllib.parse.urlencode(params)}"

    # Print the full API URL before making the API request
    print(f"API URL: {full_api_url}")

    # Make and API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

print(response.text)  # Print the entire API response for debugging
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-39.7322%2C-18.5933%2C10000&bias=proximity%3A-39.7322%2C-18.5933
# conceicao da barra - nearest hotel: Porto Marlin Hotel
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A14.7305%2C38.1435%2C10000&bias=proximity%3A14.7305%2C38.1435
# capo d'orlando - nearest hotel: Hotel Sant'Andrea
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A152.9167%2C-31.4333%2C10000&bias=proximity%3A152.9167%2C-31.4333
# port macquarie - nearest hotel: The Observatory
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-35.7353%2C-9.6658%2C10000&bias=proximity%3A-35.7353%2C-9.6658
# maceio - nearest hotel: Maceió Hostel e Pousada
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-94.781%2C31.1871%2C10000&bias=proximity%3A-94.781%2C31.1871
# diboll - nearest hotel: No hotel found
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A48.4242%2C27.271%2C10000&bias=proximity%3A48.4242%2C27.271
# mulayjah - nearest hotel: No hotel found
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A139.5%2C-20.7333%2C10000&bias=proximity%3A139.5%2C-20.7333
# mount isa - nearest hotel: Ibis Styles
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A40.2848%2C33.0381%2C10000&bias=proximity%3A40.2848%2C33.0381
# ar rutbah - nearest hotel: No hotel found
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-82.769%2C27.7692%2C10000&bias=proximity%3A-82.769%2C27.7692
# treasure island - nearest hotel: Thunderbird Beach Resort
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-121.0208%2C37.3138%2C10000&bias=proximity%3A-121.0208%2C37.3138
# newman - nearest hotel: No hotel found
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A-95.3169%2C36.3084%2C10000&bias=proximity%3A-95.3169%2C36.3084
# pryor creek - nearest hotel: Holiday Motel
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3A82.0167%2C16.5833%2C10000&bias=proximity%3A82.0167%2C16.5833
# amalapuram - nearest hotel: Homewood Suites
# API URL: https://api.geoapify.com/v2/places?categories=accommodation.hotel&apiKey=f7204ec597f44429aa07739a00bc339d&filter=circle%3
Baluchestan Province, Iran","categories":["accommodation","accommodation.hotel"],"details":["details"],"datasource":{"sourcename":"openstreetmap","attribution":"© OpenStreetMap contributors","license":"Open Database Licence","url":"https://www.openstreetmap.org/copyright","raw":{"name":"هتل قصِر","osm_id":4524803890,"name:en":"Qasr Hotel","tourism":"hotel","osm_type":"n","addr:street":"طالقانی"}},"distance":1176,"place_id":"51c07b478d09594e405928985298f7343b40f00103f9013207b30d0100000092030fd987d8aad98420d982d8b5d990d8b1"},"geometry":{"type":"Point","coordinates":[60.695604,27.20690300003494]}}]}
#                    City Country      Lat       Lng  Humidity  \
# 22   conceicao da barra      BR -18.5933  -39.7322        85
# 55       capo d'orlando      IT  38.1435   14.7305        54
# 82       port macquarie      AU -31.4333  152.9167        66
# 95               maceio      BR  -9.6658  -35.7353       100
# 103              diboll      US  31.1871  -94.7810        61
# 110            mulayjah      SA  27.2710   48.4242        21
# 120           mount isa      AU -20.7333  139.5000        32
# 142           ar rutbah      IQ  33.0381   40.2848        58
# 145     treasure island      US  27.7692  -82.7690        67
# 148              newman      US  37.3138 -121.0208        53
# 162         pryor creek      US  36.3084  -95.3169        58
# 171          amalapuram      IN  16.5833   82.0167        89
# 181             ad darb      SA  17.7229   42.2526        77
# 208                tura      IN  25.5198   90.2201        88
# 211              kourou      GF   5.1552  -52.6478        78
# 232                 hun      LY  29.1268   15.9477        53
# 241       bhimunipatnam      IN  17.8833   83.4333        80
# 324       bowling green      US  36.9903  -86.4436        41
# 351             forster      AU -32.1667  152.5167        69
# 370            adilabad      IN  19.6667   78.5333        69
# 372          al ghayzah      YE  16.2079   52.1760        83
# 388               arica      CL -18.4750  -70.3042        68
# 400              bardai      NG  11.6500    7.2333        38
# 404               khash      IR  28.2211   61.2158        17
# 406              rampur      IN  28.8167   79.0333        65
# 412             gonabad      IR  34.3529   58.6837        24
# 431      victoria falls      ZW -17.9235   25.8430        28
# 450            misratah      LY  32.3754   15.0925        66
# 459             veraval      IN  20.9000   70.3667        80
# 463            chamical      AR -30.3600  -66.3140        22
# 464          khedbrahma      IN  24.0333   73.0500        64
# 465         chake chake      TZ  -5.2459   39.7666        88
# 477          woolgoolga      AU -30.1106  153.2007        72
# 481          greenville      US  35.6127  -77.3663        73
# 499            eldorado      BR -23.7869  -54.2836        69
# 505             jasrana      IN  27.2500   78.6833        48
# 527           iranshahr      IR  27.2025   60.6848        26
#
#                        Hotel Name
# 22             Porto Marlin Hotel
# 55              Hotel Sant'Andrea
# 82                The Observatory
# 95        Maceió Hostel e Pousada
# 103                No hotel found
# 110                No hotel found
# 120                   Ibis Styles
# 142                No hotel found
# 145      Thunderbird Beach Resort
# 148                No hotel found
# 162                 Holiday Motel
# 171               Homewood Suites
# 181                No hotel found
# 208                No hotel found
# 211                   SCI Horizon
# 232                   فندق الهروج
# 241          Hotel Beach Paradise
# 324     Hyatt Place Bowling Green
# 351                No hotel found
# 370                No hotel found
# 372                فندق تاج العرب
# 388              Hotel Andalucía
# 400                No hotel found
# 404                No hotel found
# 406        تمنا ہوٹل اور ریستوران
# 412                  هتل پاسارگاد
# 431  Shearwater Explorers Village
# 450                الفندق السياحى
# 459                         Shyam
# 463                No hotel found
# 464                No hotel found
# 465             Annex Pemba Hotel
# 477       Darlington Beach Resort
# 481                   Quality Inn
# 499                 Hotel Laçador
# 505                No hotel found
# 527                      هتل قصِر

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.6,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   responsive=True,
                                   hover_cols = ["Hotel Name", "Country"]
                                     )

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
